# %% [markdown]
# ## Sentiment Analysis of Amazon Reviews on Grocery Products
#
# The notebook follows the tutorial of Amazon comprehend to generate an example sentiment analysis with Amazon reviews of grocery products:
# https://aws.amazon.com/blogs/machine-learning/detect-sentiment-from-customer-reviews-using-amazon-comprehend/

# %% [markdown]
# First import the packages.

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)  
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# Now loading the tweets from trump.

# %%
df = pd.read_csv('data/amazon_reviews_us_Grocery_v1_00.tsv', delimiter='\t',encoding='utf-8')

# %%
df.head()
# Out:
#   marketplace customer_id       review_id  product_id product_parent  \
# 0  US          42521656    R26MV8D0KG6QI6  B000SAQCWC  1.59714e+08
# 1  US          12049833    R1OF8GP57AQ1A0  B00509LVIQ  1.3868e+08
# 2  US          107642      R3VDC1QB6MC4ZZ  B00KHXESLC  2.52022e+08
# 3  US          6042304     R12FA3DCF8F9ER  B000F8JIIC  7.52728e+08
# 4  US          18123821    RTWHVNV6X4CNJ   B004ZWR9RQ  5.52139e+08
#
#                                                                                                                           product_title  \
# 0  The Cravings Place Chocolate Chunk Cookie Mix, 23-Ounce Bags (Pack of 6)
# 1  Mauna Loa Macadamias, 11 Ounce Packages
# 2  Organic Matcha Green Tea Powder - 100% Pure Matcha (No Sugar Added - Unsweetened Pure Green Tea - No Coloring Added Like Others) 4oz
# 3  15oz Raspberry Lyons Designer Dessert Syrup Sauce
# 4  Stride Spark Kinetic Fruit Sugar Free Gum, 14-Count (Pack of 12)
#
#   product_category star_rating helpful_votes total_votes vine  \
# 0  Grocery          5           0             0           N
# 1  Grocery          5           0             0           N
# 2  Grocery          5           0             0           N
# 3  Grocery          5           0             0           N
# 4  Grocery          5           0             0           N
#
#   verified_purchase                     review_headline  \
# 0  Y                 Using these for years - love them.
# 1  Y                 Wonderful
# 2  N                 Five Stars
# 3  Y                 Five Stars
# 4  Y                 Five Stars
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                             review_body  \
# 0  As a family allergic to wheat, dairy, eggs, nuts, and several other things, we love the entire Cravings Place line of products as it allows us to bake treats with minimal effort and ingredients. Most allergy-free and gluten-free mixes usually just omit one or two allergens at most, so it's great to see a mix created without many of the most common allergens. (Note these still have soy and corn). We consume these on a regular basis and have been doing so for years.
# 1  My favorite nut.  Creamy, crunchy, salty, and slightly sweet - what more could you ask for?
# 2  This green tea tastes so good! My girlfriend loves it too.
# 3  I love Melissa's brand but this is a great second when I can't get Melissa's brand.
# 4  good
#
#   review_date  Unnamed: 15  Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 0  31.08.15   NaN          NaN           NaN         NaN         NaN
# 1  31.08.15   NaN          NaN           NaN         NaN         NaN
# 2  31.08.15   NaN          NaN           NaN         NaN         NaN
# 3  31.08.15   NaN          NaN           NaN         NaN         NaN
# 4  31.08.15   NaN          NaN           NaN         NaN         NaN
#
#   Unnamed: 20 Unnamed: 21
# 0  NaN         NaN
# 1  NaN         NaN
# 2  NaN         NaN
# 3  NaN         NaN
# 4  NaN         NaN

# %%
df.shape
# Out:
# (1048573, 22)

# %% [markdown]
# The dataset in total contains 1,048,573 rows. Let's now select only a subset of it. For example, we take a look at the reviews on 31.08.15.

# %%
df_sub = df[df['review_date']=='31.08.15']

# %% [markdown]
# Next we concatenate the review headline and the review body into a single review field.

# %%
df_sub[['review_headline', 'review_body']].head()
# Out:
#                       review_headline  \
# 0  Using these for years - love them.
# 1  Wonderful
# 2  Five Stars
# 3  Five Stars
# 4  Five Stars
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                             review_body
# 0  As a family allergic to wheat, dairy, eggs, nuts, and several other things, we love the entire Cravings Place line of products as it allows us to bake treats with minimal effort and ingredients. Most allergy-free and gluten-free mixes usually just omit one or two allergens at most, so it's great to see a mix created without many of the most common allergens. (Note these still have soy and corn). We consume these on a regular basis and have been doing so for years.
# 1  My favorite nut.  Creamy, crunchy, salty, and slightly sweet - what more could you ask for?
# 2  This green tea tastes so good! My girlfriend loves it too.
# 3  I love Melissa's brand but this is a great second when I can't get Melissa's brand.
# 4  good

# %%
df_sub['review'] = df_sub[['review_headline', 'review_body']].apply(lambda x: '.'.join(x), axis=1)

# %% [markdown]
# Now generate for each review an txt file. After that we load the txt files in AWS S3 bucket.

# %%
file = 'data/amazon_grocery/amazon_grocery_review_id_{}.txt'

for index, row in df_sub.iterrows():
    review_id = row['review_id']
    with open (file.format(review_id), 'w') as f:
        f.write(str(row['review']))

# %% [markdown]
# Create table with Amazon Athena to query the results of sentiment analysis. We run the query to get the rows of results for the Amazon grocery. Download the csv and merge it with the df_sub.

# %% [markdown]
# ``` mysql
# CREATE EXTERNAL TABLE IF NOT EXISTS default.ReviewSentimentAnalysis (
#   `ImageLocation` string,
#   `Timestamp` string,
#   `Sentiment` string,
#   `Positive` string,
#   `Negative` string,
#   `Neutral` string,
#   `Mixed` string
#   )
# ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe'
# WITH SERDEPROPERTIES (
#   'serialization.format' = ',',
#   'field.delim' = ','
# ) LOCATION 's3://<bucket_name>/sentiment/'
# ;
#
# SELECT *
# FROM default.ReviewSentimentAnalysis
# WHERE imagelocation LIKE '%amazon%'
# ;
# ```

# %%
df_result = pd.read_csv('data/result_amazon_grocery.csv')
df_result.head()
# Out:
#                                                                    imagelocation  \
# 0  review-sentiment-s3-1ewrtbdvfi15z/amazon_grocery_review_id_R1CMEO6BCHWC3K.txt
# 1  review-sentiment-s3-1ewrtbdvfi15z/amazon_grocery_review_id_R1E8LRM1528KK8.txt
# 2  review-sentiment-s3-1ewrtbdvfi15z/amazon_grocery_review_id_R1D188PYGVD7GT.txt
# 3  review-sentiment-s3-1ewrtbdvfi15z/amazon_grocery_review_id_R1108D7VO1N7SZ.txt
# 4  review-sentiment-s3-1ewrtbdvfi15z/amazon_grocery_review_id_R1V5RJ1AO38HBQ.txt
#
#              timestamp sentiment  positive  negative   neutral     mixed
# 0  2019-04-26 14:17:32  POSITIVE  0.910112  0.001168  0.000472  0.088247
# 1  2019-04-26 13:46:50  POSITIVE  0.996879  0.000103  0.001988  0.001030
# 2  2019-04-26 13:45:49  POSITIVE  0.536372  0.044552  0.018155  0.400921
# 3  2019-04-26 14:13:07  POSITIVE  0.998824  0.000009  0.000480  0.000688
# 4  2019-04-26 14:18:26  NEGATIVE  0.005037  0.833196  0.000521  0.161246

# %%
import re

df_result['imagelocation']
df_result['review_id'] = df_result['imagelocation'].str.extract('review-sentiment-s3-1ewrtbdvfi15z/amazon_grocery_review_id_(.*).txt')

# %%
df_result_2 = pd.merge(df_result, df_sub, how='left', on=['review_id'])

# %%
df_result_2[df_result_2['sentiment']=='NEGATIVE'][['sentiment', 'positive', 'negative', 'neutral', 'mixed', 'product_id', 'product_title', 'review_headline', 'review_body']]\
    .sort_values(by=['negative'], ascending=False).head()
# Out:
#     sentiment  positive  negative   neutral     mixed  product_id  \
# 857  NEGATIVE  0.000017  0.999780  0.000044  0.000159  B010EOQGCC
# 844  NEGATIVE  0.000002  0.999477  0.000340  0.000181  B00A5QWXCC
# 440  NEGATIVE  0.000005  0.999342  0.000046  0.000607  B0076YG8PY
# 424  NEGATIVE  0.000014  0.999176  0.000013  0.000797  B00IYGXFX6
# 868  NEGATIVE  0.000040  0.998887  0.000111  0.000962  B001FXIMWO
#
#                                                                                                                                                                                                                                                product_title  \
# 857  Smart Sips, Chocolate Obsession Gourmet Coffee Variety Sampler Pack, 24 Count for Keurig K-cup Brewers - Chocolate Cherry Cordial, Chocolate Peanut Butter, Chocolate Amaretto, Chocolate Raspberry, White Chocolate Hazelnut Truffle, Chocolate Orange
# 844  Candy By The Pound - 5 Pound Bag of Chewy Spree
# 440  SeaSnax Grab and Go Roasted Seaweed Snack, Spicy Chipotle, 0.18-Ounce (Pack of 6)
# 424  Instant Hot Cereal, Certified Paleo, Gluten & Grain Free, Unsweetened, 6.7 oz
# 868  Halloween Mini Candy Bars Chocolate Mini Favorites Candies 5 Pound Bag
#
#                                                       review_headline  \
# 857  Waste of money
# 844  SCAM!!!!!!!!!!!!
# 440  These were absolutely horrible and I ended up throwing them away
# 424  It tasted awful. Even after adding fresh blueberries and ...
# 868  Candy Arrived Crushed.
#
#                                                                                                                                                   review_body
# 857  No flavor.  Waste of money.
# 844  i recieved a 1 pound bag of Lemonheads this is scam to get your money
# 440  These were absolutely horrible and I ended up throwing them away.  What a complete waste of money.  Took one bite and spit it out.  Lesson learned......
# 424  It tasted awful.  Even after adding fresh blueberries and cinnamon.
# 868  Candy arrived crushed. Inedible.

# %%
df_result_2[df_result_2['sentiment']=='POSITIVE'][['sentiment', 'positive', 'negative', 'neutral', 'mixed', 'product_id', 'product_title', 'review_headline', 'review_body']]\
    .sort_values(by=['positive'], ascending=False).head()
# Out:
#     sentiment  positive      negative   neutral     mixed  product_id  \
# 812  POSITIVE  0.999958  1.606578e-07  0.000012  0.000030  B0012271TS
# 85   POSITIVE  0.999898  1.986674e-06  0.000072  0.000028  B00TXN80IY
# 957  POSITIVE  0.999880  1.642476e-06  0.000038  0.000081  B000SATIGO
# 888  POSITIVE  0.999870  7.466485e-07  0.000094  0.000035  B00M8M2SKS
# 281  POSITIVE  0.999869  8.190264e-07  0.000035  0.000095  B0001VKKOO
#
#                                                                product_title  \
# 812  Paradise Tropical Tea, 1 Ounce Filter Packs (Pack of 50)
# 85   Sumatra Sizes
# 957  Davidson's Tea Bulk
# 888  Z Natural Foods Coconut Milk Powder, 100% USDA Certified Organic, 1 lb.
# 281  Bragg - All Natural Liquid Aminos All Purpose Seasoning Spray
#
#                                       review_headline  \
# 812  Love this product
# 85   This is my favorite of the varieties-fresh beans
# 957  and this is one of the best I've had
# 888  Great for Bread Recipes
# 281  love it
#
#                                                                                                                                                                                                                             review_body
# 812  The tea bags are restaurant sized - HUGE! They brew approx 10 cups of tea each, to which i then add an additional 10 cups of water. This far exceeds my expectations. And, each bag comes individually sealed. Love this product!!
# 85   This is my favorite of the varieties-fresh beans, complex flavors and outstanding value for organic coffee - just love the nose and the palate of this single source blend.
# 957  I'm a big fan of Assam tea, and this is one of the best I've had. Very malty and satisfying!
# 888  This coconut powder works perfect for my bread recipes as a powdered milk substitute. The re-seal-able pouch it comes in is just bonus! Love this product.
# 281  This is amazing for spraying onto popcorn if you like savory treats!
